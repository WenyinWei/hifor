# %%
import json
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
g = nx.karate_club_graph()
fig, ax = plt.subplots(1, 1, figsize=(8, 6));
nx.draw_networkx(g, ax=ax)

# %%
import networkx as nx
G = nx.DiGraph()

# %%
G.add_node(1)

# %%
G

# %%
G.nodes
# Out:
# NodeView((1,))

# %%
H = nx.path_graph(10)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 6));
nx.draw_networkx(H, ax=ax)

# %%
G.add_nodes_from(H)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 6));
nx.draw_networkx(H, ax=ax)
